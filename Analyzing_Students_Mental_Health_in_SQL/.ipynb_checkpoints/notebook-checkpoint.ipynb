# %% [markdown]
# **Create Database**

# %%
import psycopg2

# Establish a connection to the default 'postgres' database
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    user="postgres",
    password="Kat1eMee15",
    database="postgres"  # Connect to the default 'postgres' database
)

# Set isolation level to autocommit
conn.set_isolation_level(psycopg2.extensions.ISOLATION_LEVEL_AUTOCOMMIT)

# Create a cursor object
cursor = conn.cursor()

# Create the 'olympics' database
cursor.execute("CREATE DATABASE mental_health;")



# Close the cursor and the connection
cursor.close()
conn.close()

# %% [markdown]
# **Create tabels and import data for lesson**

# %%
# !run_scripts2
# Out:
# CREATE TABLE
# COPY 286
# All scripts executed successfully.

# %%
# Load the sql module to iPython
# %load_ext sql

# %%
# %%sql postgresql://postgres:Kat1eMee15@localhost:5432/mental_health
#
# --Check tables exist in schema = public
#
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema = 'public'
# Out:
# 1 rows affected.
# [('students',)]

# %% [markdown]
# ![Illustration of silhouetted heads](datasets/mentalhealth.jpg)

# %% [markdown]
# Does going to university in a different country affect your mental health? A Japanese international university surveyed its students in 2018 and published a study the following year that was approved by several ethical and regulatory boards.
#
# The study found that international students have a higher risk of mental health difficulties than the general population, and that social connectedness (belonging to a social group) and acculturative stress (stress associated with joining a new culture) are predictive of depression.
#
#
# Explore the `students` data using PostgreSQL to find out if you would come to a similar conclusion for international students and see if the length of stay is a contributing factor.
#
# Here is a data description of the columns you may find helpful.

# %% [markdown]
# | Field Name    | Description                                      |
# | ------------- | ------------------------------------------------ |
# | `inter_dom`     | Types of students (international or domestic)   |
# | `japanese_cate` | Japanese language proficiency                    |
# | `english_cate`  | English language proficiency                     |
# | `academic`      | Current academic level (undergraduate or graduate) |
# | `age`           | Current age of student                           |
# | `stay`          | Current length of stay in years                  |
# | `todep`         | Total score of depression (PHQ-9 test)           |
# | `tosc`          | Total score of social connectedness (SCS test)   |
# | `toas`          | Total score of acculturative stress (ASISS test) |

# %% [raw]
# -- Run this code to save the CSV file as students
# SELECT *
# FROM 'students.csv';

# %%
# %%sql
#
# SELECT *
#
# FROM students
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 286 rows affected.
# [('Inter', 'SEA', 'Male', 'Grad', 24, 4, 5, 'Long', 3, 'Average', 5, 'High', None, 'Yes', 'No', 'No', 'No', 0, 'Min', 34, 23, 9, 11, 8, 11, 2, 27, 91, 5, 5, 6, 3, 2, 1, 4, 1, 3, 4, None, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'),
#  ('Inter', 'SEA', 'Male', 'Grad', 28, 5, 1, 'Short', 4, 'High', 4, 'High', None, 'No', 'No', 'No', 'No', 2, 'Min', 48, 8, 7, 5, 4, 3, 2, 10, 39, 7, 7, 7, 4, 4, 4, 4, 1, 1, 1, None, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'),
#  ('Inter', 'SEA', 'Male', 'Grad', 25, 4, 6, 'Long', 4, 'High', 4, 'High', 'Yes', 'Yes', 'No', 'No', 'No', 2, 'Min', 41, 13, 4, 7, 6, 4, 3, 14, 51, 3, 3, 3, 1, 1, 2, 1, 1, 1, 1, None, 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'),
# ...

# %%
# %%sql
#
# --Count the number of records
#
# SELECT COUNT(*) AS total_records
#
#
# FROM students;
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 1 rows affected.
# [(286,)]

# %%
# %%sql
#
# --Count the number of International Students
#
# SELECT COUNT(inter_dom) AS count_int_student
#
# FROM students
# WHERE inter_dom = 'Inter';
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 1 rows affected.
# [(201,)]

# %%
# %%sql
#
# --Count the number of Domestic Students
#
# SELECT COUNT(inter_dom) AS count_dom_student
#
# FROM students
# WHERE inter_dom = 'Dom';
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 1 rows affected.
# [(67,)]

# %%
# %%sql
#
# --Count the number of Null Values
#
# SELECT COUNT(inter_dom) AS count_dom_student
#
# FROM students
# WHERE inter_dom IS NULL;
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 1 rows affected.
# [(0,)]

# %%
# %%sql
#
# -- Count the number of students by type
#
# SELECT COUNT(inter_dom) AS count_int_dom
#
# FROM students
#
# GROUP BY inter_dom;
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 3 rows affected.
# [(0,), (67,), (201,)]

# %%
# %%sql
#
# -- Student Statisitics for PHQ-9, SCS and ASIS tests
#
# SELECT inter_dom,
# 	   ROUND(MIN(todep),2) as min_phq,
# 	   ROUND(MAX(todep),2) as max_phq,
# 	   ROUND(AVG(todep),2) as avg_phq,
# 	   ROUND(MIN(tosc),2) as min_scs,
# 	   ROUND(MAX(tosc),2) as max_scs,
# 	   ROUND(AVG(tosc),2) as avg_scs,
#    	   ROUND(MIN(toas),2) as min_as,
# 	   ROUND(MAX(toas),2) as max_as,
# 	   ROUND(AVG(toas),2) as avg_as
#
# FROM students
#
# GROUP BY inter_dom;
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 3 rows affected.
# [(None, None, None, None, None, None, None, None, None, None),
#  ('Dom', Decimal('0.00'), Decimal('23.00'), Decimal('8.61'), Decimal('8.00'), Decimal('48.00'), Decimal('37.64'), Decimal('36.00'), Decimal('112.00'), Decimal('62.84')),
#  ('Inter', Decimal('0.00'), Decimal('25.00'), Decimal('8.04'), Decimal('11.00'), Decimal('48.00'), Decimal('37.42'), Decimal('36.00'), Decimal('145.00'), Decimal('75.56'))]

# %%
# %%sql
#
# -- Internationa; Student Statisitics for PHQ-9, SCS and ASIS tests
#
# SELECT inter_dom,
# 	   ROUND(MIN(todep),2) as min_phq,
# 	   ROUND(MAX(todep),2) as max_phq,
# 	   ROUND(AVG(todep),2) as avg_phq,
# 	   ROUND(MIN(tosc),2) as min_scs,
# 	   ROUND(MAX(tosc),2) as max_scs,
# 	   ROUND(AVG(tosc),2) as avg_scs,
#    	   ROUND(MIN(toas),2) as min_as,
# 	   ROUND(MAX(toas),2) as max_as,
# 	   ROUND(AVG(toas),2) as avg_as
#
# FROM students
# WHERE inter_dom = 'Inter'
# GROUP BY inter_dom;
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 1 rows affected.
# [('Inter', Decimal('0.00'), Decimal('25.00'), Decimal('8.04'), Decimal('11.00'), Decimal('48.00'), Decimal('37.42'), Decimal('36.00'), Decimal('145.00'), Decimal('75.56'))]

# %%
# %%sql
#
# -- Impact of length of stay
# SELECT round(AVG(stay),2) as stay,
# 	   ROUND(AVG(todep),2) as average_phq,
# 	   ROUND(AVG(tosc),2) as average_scs,
# 	   ROUND(AVG(toas),2) as average_as
#
# FROM students
# WHERE inter_dom = 'Inter'
# GROUP BY stay
# ORDER BY stay DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/mental_health
# 9 rows affected.
# [(Decimal('10.00'), Decimal('13.00'), Decimal('32.00'), Decimal('50.00')),
#  (Decimal('8.00'), Decimal('10.00'), Decimal('44.00'), Decimal('65.00')),
#  (Decimal('7.00'), Decimal('4.00'), Decimal('48.00'), Decimal('45.00')),
#  (Decimal('6.00'), Decimal('6.00'), Decimal('38.00'), Decimal('58.67')),
#  (Decimal('5.00'), Decimal('0.00'), Decimal('34.00'), Decimal('91.00')),
#  (Decimal('4.00'), Decimal('8.57'), Decimal('33.93'), Decimal('87.71')),
#  (Decimal('3.00'), Decimal('9.09'), Decimal('37.13'), Decimal('78.00')),
#  (Decimal('2.00'), Decimal('8.28'), Decimal('37.08'), Decimal('77.67')),
#  (Decimal('1.00'), Decimal('7.48'), Decimal('38.11'), Decimal('72.80'))]

# %%
import psycopg2

# Establish a connection to the default 'postgres' database
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    user="postgres",
    password="Kat1eMee15",
    database="postgres"  # Connect to the default 'postgres' database
)

# Set isolation level to autocommit
conn.set_isolation_level(psycopg2.extensions.ISOLATION_LEVEL_AUTOCOMMIT)

# Create a cursor object
cursor = conn.cursor()

# Terminate active connections to the 'database_design' database
cursor.execute("SELECT pg_terminate_backend (pg_stat_activity.pid) FROM pg_stat_activity WHERE pg_stat_activity.datname = 'mental_health';")

# Drop the 'database_design' database
cursor.execute("DROP DATABASE IF EXISTS mental_health;")

# Close the cursor and the connection
cursor.close()
conn.close()
